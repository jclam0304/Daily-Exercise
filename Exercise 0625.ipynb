# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas_datareader.data as web

# %%
df = web.DataReader("AAPL","yahoo",start="2017-9-1", end="2020-6-20") #Apple Share Price

# %%
df.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-08-31  164.520004  163.479996  163.639999  164.000000  26785100.0
# 2017-09-01  164.940002  163.630005  164.800003  164.050003  16591100.0
# 2017-09-05  164.250000  160.559998  163.750000  162.080002  29468500.0
# 2017-09-06  162.990005  160.520004  162.710007  161.910004  21651700.0
# 2017-09-07  162.240005  160.360001  162.089996  161.259995  21928500.0
#
#              Adj Close
# Date
# 2017-08-31  157.809616
# 2017-09-01  157.857742
# 2017-09-05  155.962082
# 2017-09-06  155.798492
# 2017-09-07  155.173035

# %%
P = df["Adj Close"]

# %%
P.plot()

# %%
r = P.diff()/P

# %%
r[-50:].plot()

# %%
P.rolling(window=20).mean()
# Out:
# Date
# 2017-08-31           NaN
# 2017-09-01           NaN
# 2017-09-05           NaN
# 2017-09-06           NaN
# 2017-09-07           NaN
#                  ...
# 2020-06-15    326.310500
# 2020-06-16    328.166499
# 2020-06-17    330.088998
# 2020-06-18    331.713998
# 2020-06-19    333.357498
# Name: Adj Close, Length: 705, dtype: float64

# %%
P.plot() #Adj.close price
P.rolling(window=20).mean().plot() #20days moving average
P.rolling(window=60).mean().plot() #60days moving average
